# %%
import os
import numpy as np
import matplotlib.pyplot as plt # type: ignore
from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt # type: ignore
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

train_data = train_datagen.flow_from_directory(
    'dataset/',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = train_datagen.flow_from_directory(
    'dataset/',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 4658 images belonging to 6 classes.
# Found 1994 images belonging to 6 classes.

# %%
print(train_data.class_indices)
# Out:
# {'Potato___Early_blight': 0, 'Potato___Late_blight': 1, 'Potato___healthy': 2, 'Tomato___Early_blight': 3, 'Tomato___Late_blight': 4, 'Tomato___healthy': 5}

# %%
for image_batch, label_batch in train_data:
    plt.imshow(image_batch[0])
    plt.title(label_batch[0])
    plt.show()
    break

# %%
from tensorflow.keras.applications import MobileNetV2 # type: ignore
from tensorflow.keras.models import Model # type: ignore
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout # type: ignore

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224,224,3))
base_model.trainable = False  # freeze base layers

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(6, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
from tensorflow.keras.optimizers import Adam # type: ignore
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=15,
    verbose=1
)
# Out:
# Epoch 1/15
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 43s 285ms/step - accuracy: 0.6449 - loss: 0.9934 - val_accuracy: 0.8586 - val_loss: 0.4815
# Epoch 2/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - accuracy: 0.8431 - loss: 0.4795 - val_accuracy: 0.8902 - val_loss: 0.3300
# Epoch 3/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - accuracy: 0.8806 - loss: 0.3549 - val_accuracy: 0.9097 - val_loss: 0.2659
# Epoch 4/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 42s 286ms/step - accuracy: 0.9025 - loss: 0.2957 - val_accuracy: 0.9193 - val_loss: 0.2326
# Epoch 5/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 42s 288ms/step - accuracy: 0.9195 - loss: 0.2455 - val_accuracy: 0.9288 - val_loss: 0.2069
# Epoch 6/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 42s 289ms/step - accuracy: 0.9294 - loss: 0.2212 - val_accuracy: 0.9338 - val_loss: 0.1975
# Epoch 7/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 43s 292ms/step - accuracy: 0.9322 - loss: 0.1998 - val_accuracy: 0.9383 - val_loss: 0.1866
# Epoch 8/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 43s 292ms/step - accuracy: 0.9347 - loss: 0.1867 - val_accuracy: 0.9388 - val_loss: 0.1771
# Epoch 9/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 43s 292ms/step - accuracy: 0.9459 - loss: 0.1643 - val_accuracy: 0.9468 - val_loss: 0.1624
# Epoch 10/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 42s 291ms/step - accuracy: 0.9500 - loss: 0.1496 - val_accuracy: 0.9504 - val_loss: 0.1528
# Epoch 11/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 43s 294ms/step - accuracy: 0.9558 - loss: 0.1435 - val_accuracy: 0.9493 - val_loss: 0.1511
# Epoch 12/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 43s 296ms/step - accuracy: 0.9607 - loss: 0.1302 - val_accuracy: 0.9504 - val_loss: 0.1433
# Epoch 13/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 44s 301ms/step - accuracy: 0.9592 - loss: 0.1232 - val_accuracy: 0.9493 - val_loss: 0.1430
# Epoch 14/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 46s 314ms/step - accuracy: 0.9667 - loss: 0.1155 - val_accuracy: 0.9534 - val_loss: 0.1373
# Epoch 15/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 0.9689 - loss: 0.1077 - val_accuracy: 0.9544 - val_loss: 0.1325

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
for layer in base_model.layers[-20:]:
    layer.trainable = True
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_data, validation_data=val_data, epochs=5)
# Out:
# Epoch 1/5
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 52s 345ms/step - accuracy: 0.8806 - loss: 0.3369 - val_accuracy: 0.9463 - val_loss: 0.1501
# Epoch 2/5
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 51s 350ms/step - accuracy: 0.9347 - loss: 0.1874 - val_accuracy: 0.9498 - val_loss: 0.1441
# Epoch 3/5
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 51s 352ms/step - accuracy: 0.9476 - loss: 0.1530 - val_accuracy: 0.9498 - val_loss: 0.1398
# Epoch 4/5
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 52s 358ms/step - accuracy: 0.9596 - loss: 0.1196 - val_accuracy: 0.9534 - val_loss: 0.1358
# Epoch 5/5
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 54s 369ms/step - accuracy: 0.9665 - loss: 0.1022 - val_accuracy: 0.9534 - val_loss: 0.1341
